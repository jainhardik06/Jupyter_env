# %%
import pandas as pd

# %% [markdown]
# # Pandas DataFrames - Learning Notes
#
# ## What is Pandas?
# - Pandas is a Python library for data manipulation and analysis.
# - It provides two main data structures: **Series** (1D) and **DataFrame** (2D).
#
# ## Key Concepts Covered
# 1. **Importing pandas**: Use `import pandas as pd`.
# 2. **Creating DataFrames**: You can create a DataFrame from a dictionary.
# 3. **Reading CSV files**: Use `pd.read_csv('filename.csv')` to load data.
# 4. **Data Analysis Methods**:
#    - `.max()`: Find the maximum value in a column.
#    - `.mean()`: Calculate the average value in a column.
#    - Filtering: Select rows based on conditions.
# 5. **Data Cleaning (Munging)**:
#    - Use `.fillna(0, inplace=True)` to replace missing values with 0.
#
# ## Example Workflow
# - Import pandas
# - Create or load a DataFrame
# - Analyze data (max, mean, filter)
# - Clean data (handle missing values)
#
# ---
# Use these notes as a quick reference for your pandas DataFrame operations!

# %%
retrive_csv = pd.read_csv('nyc_weather.csv')
print(retrive_csv)
# Out:
#                                                                                                 Unnamed: 0  \
# EST       Temperature DewPoint Humidity Sea Level PressureIn VisibilityMiles WindSpeedMPH  PrecipitationIn
# 1/1/2016  38          23       52       30.03                10              8                           0
# 1/2/2016  36          18       46       30.02                10              7                           0
# 1/3/2016  40          21       47       29.86                10              8                           0
# 1/4/2016  25          9        44       30.05                10              9                           0
# 1/5/2016  20          -3       41       30.57                10              5                           0
# 1/6/2016  33          4        35       30.5                 10              4                           0
# 1/7/2016  39          11       33       30.28                10              2                           0
# 1/8/2016  39          29       64       30.2                 10              4                           0
# 1/9/2016  44          38       77       30.16                9               8                           T
# 1/10/2016 50          46       71       29.59                4               NaN                       1.8
# 1/11/2016 33          8        37       29.92                10              NaN                         0
# 1/12/2016 35          15       53       29.85                10              6                           T
# 1/13/2016 26          4        42       29.94                10              10                          0
# 1/14/2016 30          12       47       29.95                10              5                           T
# 1/15/2016 43          31       62       29.82                9               5                           T
# 1/16/2016 47          37       70       29.52                8               7                        0.24
# 1/17/2016 36          23       66       29.78                8               6                        0.05
# 1/18/2016 25          6        53       29.83                9               12                          T
# 1/19/2016 22          3        42       30.03                10              11                          0
# 1/20/2016 32          15       49       30.13                10              6                           0
# 1/21/2016 31          11       45       30.15                10              6                           0
# 1/22/2016 26          6        41       30.21                9               NaN                      0.01
# 1/23/2016 26          21       78       29.77                1               16                       2.31
# 1/24/2016 28          11       53       29.92                8               6                           T
# 1/25/2016 34          18       54       30.25                10              3                           0
# 1/26/2016 43          29       56       30.03                10              7                           0
# 1/27/2016 41          22       45       30.03                10              7                           T
# 1/28/2016 37          20       51       29.9                 10              5                           0
# 1/29/2016 36          21       50       29.58                10              8                           0
# 1/30/2016 34          16       46       30.01                10              7                           0
# 1/31/2016 46          28       52       29.9                 10              5                           0
#
#                                                                                            Unnamed: 1  \
# EST       Temperature DewPoint Humidity Sea Level PressureIn VisibilityMiles WindSpeedMPH  CloudCover
# 1/1/2016  38          23       52       30.03                10              8                      5
# 1/2/2016  36          18       46       30.02                10              7                      3
# 1/3/2016  40          21       47       29.86                10              8                      1
# 1/4/2016  25          9        44       30.05                10              9                      3
# 1/5/2016  20          -3       41       30.57                10              5                      0
# 1/6/2016  33          4        35       30.5                 10              4                      0
# 1/7/2016  39          11       33       30.28                10              2                      3
# 1/8/2016  39          29       64       30.2                 10              4                      8
# 1/9/2016  44          38       77       30.16                9               8                      8
# 1/10/2016 50          46       71       29.59                4               NaN                    7
# 1/11/2016 33          8        37       29.92                10              NaN                    1
# 1/12/2016 35          15       53       29.85                10              6                      4
# 1/13/2016 26          4        42       29.94                10              10                     0
# 1/14/2016 30          12       47       29.95                10              5                      7
# 1/15/2016 43          31       62       29.82                9               5                      2
# 1/16/2016 47          37       70       29.52                8               7                      7
# 1/17/2016 36          23       66       29.78                8               6                      6
# 1/18/2016 25          6        53       29.83                9               12                     2
# 1/19/2016 22          3        42       30.03                10              11                     1
# 1/20/2016 32          15       49       30.13                10              6                      2
# 1/21/2016 31          11       45       30.15                10              6                      1
# 1/22/2016 26          6        41       30.21                9               NaN                    3
# 1/23/2016 26          21       78       29.77                1               16                     8
# 1/24/2016 28          11       53       29.92                8               6                      3
# 1/25/2016 34          18       54       30.25                10              3                      2
# 1/26/2016 43          29       56       30.03                10              7                      2
# 1/27/2016 41          22       45       30.03                10              7                      3
# 1/28/2016 37          20       51       29.9                 10              5                      1
# 1/29/2016 36          21       50       29.58                10              8                      4
# 1/30/2016 34          16       46       30.01                10              7                      0
# 1/31/2016 46          28       52       29.9                 10              5                      0
#
#                                                                                           Unnamed: 2  \
# EST       Temperature DewPoint Humidity Sea Level PressureIn VisibilityMiles WindSpeedMPH     Events
# 1/1/2016  38          23       52       30.03                10              8                   NaN
# 1/2/2016  36          18       46       30.02                10              7                   NaN
# 1/3/2016  40          21       47       29.86                10              8                   NaN
# 1/4/2016  25          9        44       30.05                10              9                   NaN
# 1/5/2016  20          -3       41       30.57                10              5                   NaN
# 1/6/2016  33          4        35       30.5                 10              4                   NaN
# 1/7/2016  39          11       33       30.28                10              2                   NaN
# 1/8/2016  39          29       64       30.2                 10              4                   NaN
# 1/9/2016  44          38       77       30.16                9               8                  Rain
# 1/10/2016 50          46       71       29.59                4               NaN                Rain
# 1/11/2016 33          8        37       29.92                10              NaN                 NaN
# 1/12/2016 35          15       53       29.85                10              6                   NaN
# 1/13/2016 26          4        42       29.94                10              10                  NaN
# 1/14/2016 30          12       47       29.95                10              5                   NaN
# 1/15/2016 43          31       62       29.82                9               5                   NaN
# 1/16/2016 47          37       70       29.52                8               7                  Rain
# 1/17/2016 36          23       66       29.78                8               6              Fog-Snow
# 1/18/2016 25          6        53       29.83                9               12                 Snow
# 1/19/2016 22          3        42       30.03                10              11                  NaN
# 1/20/2016 32          15       49       30.13                10              6                   NaN
# 1/21/2016 31          11       45       30.15                10              6                   NaN
# 1/22/2016 26          6        41       30.21                9               NaN                Snow
# 1/23/2016 26          21       78       29.77                1               16             Fog-Snow
# 1/24/2016 28          11       53       29.92                8               6                  Snow
# 1/25/2016 34          18       54       30.25                10              3                   NaN
# 1/26/2016 43          29       56       30.03                10              7                   NaN
# 1/27/2016 41          22       45       30.03                10              7                  Rain
# 1/28/2016 37          20       51       29.9                 10              5                   NaN
# 1/29/2016 36          21       50       29.58                10              8                   NaN
# 1/30/2016 34          16       46       30.01                10              7                   NaN
# 1/31/2016 46          28       52       29.9                 10              5                   NaN
#
#                                                                                                Unnamed: 3
# EST       Temperature DewPoint Humidity Sea Level PressureIn VisibilityMiles WindSpeedMPH  WindDirDegrees
# 1/1/2016  38          23       52       30.03                10              8                        281
# 1/2/2016  36          18       46       30.02                10              7                        275
# 1/3/2016  40          21       47       29.86                10              8                        277
# 1/4/2016  25          9        44       30.05                10              9                        345
# 1/5/2016  20          -3       41       30.57                10              5                        333
# 1/6/2016  33          4        35       30.5                 10              4                        259
# 1/7/2016  39          11       33       30.28                10              2                        293
# 1/8/2016  39          29       64       30.2                 10              4                         79
# 1/9/2016  44          38       77       30.16                9               8                         76
# 1/10/2016 50          46       71       29.59                4               NaN                      109
# 1/11/2016 33          8        37       29.92                10              NaN                      289
# 1/12/2016 35          15       53       29.85                10              6                        235
# 1/13/2016 26          4        42       29.94                10              10                       284
# 1/14/2016 30          12       47       29.95                10              5                        266
# 1/15/2016 43          31       62       29.82                9               5                        101
# 1/16/2016 47          37       70       29.52                8               7                        340
# 1/17/2016 36          23       66       29.78                8               6                        345
# 1/18/2016 25          6        53       29.83                9               12                       293
# 1/19/2016 22          3        42       30.03                10              11                       293
# 1/20/2016 32          15       49       30.13                10              6                        302
# 1/21/2016 31          11       45       30.15                10              6                        312
# 1/22/2016 26          6        41       30.21                9               NaN                       34
# 1/23/2016 26          21       78       29.77                1               16                        42
# 1/24/2016 28          11       53       29.92                8               6                        327
# 1/25/2016 34          18       54       30.25                10              3                        286
# 1/26/2016 43          29       56       30.03                10              7                        244
# 1/27/2016 41          22       45       30.03                10              7                        311
# 1/28/2016 37          20       51       29.9                 10              5                        234
# 1/29/2016 36          21       50       29.58                10              8                        298
# 1/30/2016 34          16       46       30.01                10              7                        257
# 1/31/2016 46          28       52       29.9                 10              5                        241

# %%
# max method
max_temp = retrive_csv['Temperature'].max()
print(max_temp)

# avg method
avg_wind = retrive_csv['WindSpeedMPH'].mean()
print(avg_wind)

dates_rain = retrive_csv['EST'][retrive_csv['Events'] == 'Rain']
print(dates_rain)
# Out:
# 50
# 6.892857142857143
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
# data munging or data cleaning

retrive_csv.fillna(0, inplace=True)
print(retrive_csv)
avg_wind = retrive_csv['WindSpeedMPH'].mean()
print(avg_wind)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                10           8.0               0           5         0
# 1                10           7.0               0           3         0
# 2                10           8.0               0           1         0
# 3                10           9.0               0           3         0
# 4                10           5.0               0           0         0
# 5                10           4.0               0           0         0
# 6                10           2.0               0           3         0
# 7                10           4.0               0           8         0
# 8                 9           8.0               T           8      Rain
# 9                 4           0.0             1.8           7      Rain
# 10               10           0.0               0           1         0
# 11               10           6.0               T           4         0
# 12               10          10.0               0           0         0
# 13               10           5.0               T           7         0
# 14                9           5.0               T           2         0
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1         0
# 19               10           6.0               0           2         0
# 20               10           6.0               0           1         0
# 21                9           0.0            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2         0
# 25               10           7.0               0           2         0
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1         0
# 28               10           8.0               0           4         0
# 29               10           7.0               0           0         0
# 30               10           5.0               0           0         0
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241
# 6.225806451612903
